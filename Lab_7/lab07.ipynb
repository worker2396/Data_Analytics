# %%
import numpy as np
from cmdstanpy import CmdStanModel

# %% [markdown]
# Excercise 1

# %%
#Roman Dembrovskyi
F = 5
L = 11
N = (L+F)*100

model = CmdStanModel(stan_file='code_1.stan')
data = {'N': N}
result = model.sample(data=data, chains = 4)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |▉         | 00:00 Iteration:   1 / 1000 [  0%]  (Sampling)
#
#
# chain 1 |█▎        | 00:00 Iteration: 100 / 1000 [ 10%]  (Sampling)
#
#
# chain 1 |█▊        | 00:01 Iteration: 200 / 1000 [ 20%]  (Sampling)
#
#
# chain 1 |██▎       | 00:02 Iteration: 300 / 1000 [ 30%]  (Sampling)
#
#
# chain 1 |██▋       | 00:02 Iteration: 400 / 1000 [ 40%]  (Sampling)
#
#
# chain 1 |███▏      | 00:03 Iteration: 500 / 1000 [ 50%]  (Sampling)
#
#
# chain 1 |███▋      | 00:03 Iteration: 600 / 1000 [ 60%]  (Sampling)
#
#
# chain 1 |████      | 00:04 Iteration: 700 / 1000 [ 70%]  (Sampling)
#
#
# chain 1 |████▌     | 00:04 Iteration: 800 / 1000 [ 80%]  (Sampling)
#
#
# chain 1 |█████     | 00:05 Iteration: 900 / 1000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 00:05 Sampling completed
# chain 2 |██████████| 00:05 Sampling completed
#
# chain 3 |██████████| 00:05 Sampling completed
# chain 4 |██████████| 00:05 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
result.draws_pd()
# Out:
#       lp__  accept_stat__  theta      y[1]       y[2]      y[3]      y[4]  \
# 0      0.0            0.0   0.01 -1.425070  21.870200  0.653447 -0.141605
# 1      0.0            0.0   0.01  0.464166   0.673976  0.444181 -0.620547
# 2      0.0            0.0   0.01 -0.559143   2.048270  0.490969 -0.900371
# 3      0.0            0.0   0.01 -0.574435  -0.229947 -1.034240  0.107147
# 4      0.0            0.0   0.01 -0.932578   0.361533 -2.089150 -2.542020
# ...    ...            ...    ...       ...        ...       ...       ...
# 3995   0.0            0.0   0.01  0.019276   1.309310  1.149980 -0.914096
# 3996   0.0            0.0   0.01  2.558580   0.039502  0.655019  0.849223
# 3997   0.0            0.0   0.01  0.323288   0.040069 -0.654090 -0.111825
# 3998   0.0            0.0   0.01  1.391960  -0.540075  0.750226  0.678511
# 3999   0.0            0.0   0.01 -0.130439  -0.001025 -0.170702 -0.503035
#
#           y[5]      y[6]      y[7]  ...    y[1591]   y[1592]   y[1593]  \
# 0     1.210820 -0.953549 -0.035348  ...   0.287973  0.909026 -2.137850
# 1    -2.253270  1.021660  0.135223  ...   0.145924  0.252022 -0.704071
# 2    -1.209350  0.619369  2.951090  ...   1.104360 -0.630518  0.574203
# 3     0.716227 -0.747937  0.218909  ...  -2.355590 -0.897594  1.541040
# 4    -0.014434  0.267285 -0.126835  ...   2.734290  0.268383 -0.253632
# ...        ...       ...       ...  ...        ...       ...       ...
# 3995  1.368570  1.097520 -0.302019  ...  -0.183855  0.754734 -0.284362
# 3996  0.116379  0.381338  0.828343  ...  -0.456036  0.927406  1.232500
# 3997 -0.389457  0.020955  0.548990  ...  15.576500  0.352412 -0.721492
# 3998 -0.023008  0.536853 -0.190070  ...  -1.381440  0.239167 -0.163070
# 3999  0.625248  0.986558  1.257160  ...  -3.308040 -0.274332 -1.706200
#
#        y[1594]   y[1595]   y[1596]   y[1597]   y[1598]   y[1599]   y[1600]
# 0     0.307260 -0.577590 -1.969290  1.231060 -0.410364 -1.102180 -0.979945
# 1    -1.127360 -1.816100 -1.161010  0.805083  1.319750 -0.946031 -1.547940
# 2    -0.682749  0.182179 -0.974562 -0.362773  0.339305 -0.104262  0.727493
# 3     0.892276 -0.198957  1.524090 -0.692129  0.221404  0.481064 -1.154850
# 4     0.401798 -0.299238 -0.520979  0.253337 -0.548997  0.129810  0.027765
# ...        ...       ...       ...       ...       ...       ...       ...
# 3995  0.224748  0.527492 -0.426561  1.734590  0.011546  0.383150 -0.305424
# 3996  2.048010  0.556518  1.639870  0.063247 -0.638440  1.925610 -0.012717
# 3997 -0.445548 -0.162332  1.502640 -0.189477 -0.781905  0.621492  0.970434
# 3998 -0.260789  0.677943 -2.055020 -0.266190 -0.400820 -0.068040 -0.304917
# 3999  0.120383 -1.072430 -1.437570 -0.806157 -1.174890 -0.565332 -0.094546
#
# [4000 rows x 1603 columns]

# %%
model_2 = CmdStanModel(stan_file='code_2.stan')
data_2 = {'N': N}
result_2 = model_2.sample(data=data_2, chains = 4)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |▉         | 00:01 Iteration:   1 / 1000 [  0%]  (Sampling)
#
#
# chain 1 |█▎        | 00:03 Iteration: 100 / 1000 [ 10%]  (Sampling)
#
#
# chain 1 |█▊        | 00:04 Iteration: 200 / 1000 [ 20%]  (Sampling)
#
#
# chain 1 |██▎       | 00:06 Iteration: 300 / 1000 [ 30%]  (Sampling)
#
#
# chain 1 |██▋       | 00:08 Iteration: 400 / 1000 [ 40%]  (Sampling)
#
#
# chain 1 |███▏      | 00:10 Iteration: 500 / 1000 [ 50%]  (Sampling)
#
#
# chain 1 |███▋      | 00:11 Iteration: 600 / 1000 [ 60%]  (Sampling)
#
#
# chain 1 |████      | 00:13 Iteration: 700 / 1000 [ 70%]  (Sampling)
#
#
# chain 1 |████▌     | 00:14 Iteration: 800 / 1000 [ 80%]  (Sampling)
#
#
# chain 1 |█████     | 00:16 Iteration: 900 / 1000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 00:16 Sampling completed
# chain 2 |██████████| 00:16 Sampling completed
# chain 3 |██████████| 00:16 Sampling completed
# chain 4 |██████████| 00:16 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
result_2.draws_pd()
# Out:
#       lp__  accept_stat__    X[1,1]    X[2,1]    X[3,1]    X[4,1]    X[5,1]  \
# 0      0.0            0.0 -1.571740  0.407067  0.845713  0.315652 -0.545726
# 1      0.0            0.0  0.697826  1.593440  0.591665  1.381780  1.046990
# 2      0.0            0.0  0.030212 -1.007710 -0.237049 -1.784870 -0.006265
# 3      0.0            0.0  0.182070  0.443694  0.355369 -0.591528  0.768231
# 4      0.0            0.0  0.385937 -0.865104  2.159030 -0.852477  0.481066
# ...    ...            ...       ...       ...       ...       ...       ...
# 3995   0.0            0.0 -0.701825 -1.356290  0.039067 -0.232269  0.219819
# 3996   0.0            0.0  2.263150  0.572186  1.367310 -0.334457  0.591397
# 3997   0.0            0.0  1.367480  1.971830 -0.488767 -0.908816  0.866970
# 3998   0.0            0.0  0.682128 -0.035422 -0.688160 -0.625386  0.929043
# 3999   0.0            0.0  0.284163  0.045005  0.175406 -0.562961  0.137421
#
#         X[6,1]    X[7,1]    X[8,1]  ...   y[1591]   y[1592]   y[1593]  \
# 0     1.218420  0.052152  0.012819  ... -1.104520 -1.398200 -0.271180
# 1    -0.259864  1.329950 -1.724570  ... -1.216930 -0.595466 -0.583858
# 2     1.668460  0.815553 -0.958271  ...  2.448510 -0.231301  3.958760
# 3    -0.824468  1.950160  2.140550  ...  4.580900 -0.464475  0.839352
# 4    -0.605505  2.510670  0.369843  ... -1.177910 -0.996432  1.442930
# ...        ...       ...       ...  ...       ...       ...       ...
# 3995  0.906869 -0.826291  0.728448  ...  3.056520 -2.587440 -2.554610
# 3996  0.293473  0.807140  0.845594  ...  2.541820 -1.477810 -2.420120
# 3997 -1.271640 -1.044410 -1.028000  ...  3.829790 -1.335380  6.339650
# 3998 -0.730167  0.501660  0.625838  ...  0.913147  2.326170 -0.791313
# 3999 -0.103127 -0.599039 -0.236562  ... -0.647817  6.491570 -0.304437
#
#        y[1594]   y[1595]   y[1596]   y[1597]   y[1598]   y[1599]   y[1600]
# 0     6.560340 -0.980379  1.610640  0.693134  3.752550 -1.041090 -0.259340
# 1    -0.081591 -2.040100  2.551240  3.970590 -1.605910  0.797288  0.623009
# 2    -0.755305  3.079450 -0.135591 -3.470990 -2.791990  1.144050 -1.289050
# 3    -0.637615 -2.389150 -1.633470 -2.864570  2.902730  2.210740  1.789180
# 4    -0.877380  1.840270  0.297533  3.226550 -1.486250 -4.970510  2.819290
# ...        ...       ...       ...       ...       ...       ...       ...
# 3995  0.983343 -0.861659  0.717419  2.386660 -3.328560  5.575260  0.273646
# 3996  2.903100 -3.151870 -1.590160  1.242710  2.234430  0.530094  0.112933
# 3997 -3.811460  3.882850  1.191350  2.200060 -0.130448  1.925590 -4.081450
# 3998 -1.768950 -0.422501  2.154010 -1.332890  1.643170  1.610590  1.748010
# 3999  3.553890  2.298280  1.858440 -2.792710  1.828570  3.246560 -0.360207
#
# [4000 rows x 6405 columns]

# %% [markdown]
# Excercise 2

# %%
y = result_2.stan_variable("y")[0].tolist()

# %%
model_3 = CmdStanModel(stan_file='code_3.stan')

data = {'N': N, 'y': y}
result_3 = model_3.sample(data=data, chains = 4)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |█▎        | 00:00 Iteration:  100 / 2000 [  5%]  (Warmup)
#
#
# chain 1 |█████▉    | 00:01 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
# chain 1 |██████▊   | 00:02 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
# chain 1 |███████▋  | 00:04 Iteration: 1400 / 2000 [ 70%]  (Sampling)
# chain 1 |████████▏ | 00:04 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
# chain 1 |████████▋ | 00:05 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
#
# chain 1 |█████████ | 00:06 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
# chain 1 |█████████▌| 00:07 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 00:08 Iteration: 1900 / 2000 [ 95%]  (Sampling)
#
#
# chain 1 |██████████| 00:08 Sampling completed
# chain 2 |██████████| 00:08 Sampling completed
# chain 3 |██████████| 00:08 Sampling completed
# chain 4 |██████████| 00:08 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
import arviz as az
arviz_result_3 = az.from_cmdstanpy(posterior=result_3)

# %%
arviz_result_3
# Out:
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats

# %%
model_4 = CmdStanModel(stan_file='code_4.stan')
result_4 = model_4.sample(data=data, chains = 4)
arviz_result_4 = az.from_cmdstanpy(posterior=result_4)
arviz_result_4
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
#
# chain 1 |▍         | 00:00 Status
#
# chain 1 |▉         | 00:00 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
# chain 1 |█▎        | 00:00 Iteration:  100 / 2000 [  5%]  (Warmup)
#
#
# chain 1 |██▎       | 00:01 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
#
# chain 1 |██▋       | 00:01 Iteration:  400 / 2000 [ 20%]  (Warmup)
#
#
# chain 1 |███▋      | 00:01 Iteration:  600 / 2000 [ 30%]  (Warmup)
#
#
# chain 1 |████▌     | 00:01 Iteration:  800 / 2000 [ 40%]  (Warmup)
# chain 1 |█████▍    | 00:01 Iteration: 1000 / 2000 [ 50%]  (Warmup)
#
#
#
#
# chain 1 |██████▎   | 00:03 Iteration: 1100 / 2000 [ 55%]  (Sampling)
#
#
# chain 1 |██████▊   | 00:04 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
# chain 1 |███████▎  | 00:06 Iteration: 1300 / 2000 [ 65%]  (Sampling)
#
#
# chain 1 |███████▋  | 00:07 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
# chain 1 |████████▏ | 00:08 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
# chain 1 |████████▋ | 00:09 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
#
# chain 1 |█████████ | 00:10 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
#
# chain 1 |█████████▌| 00:11 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 00:12 Sampling completed
# chain 2 |██████████| 00:12 Sampling completed
# chain 3 |██████████| 00:12 Sampling completed
# chain 4 |██████████| 00:12 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats

# %%
compare_dict = {"code_3": arviz_result_3, "code_4": arviz_result_4}
az_compare = az.compare(compare_dict)
az_compare
# Out:
# d:\work\Anaconda\envs\data_sc\lib\site-packages\arviz\stats\stats.py:248: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ics = ics.append([ic_func(dataset, pointwise=True, scale=scale, var_name=var_name)])
# d:\work\Anaconda\envs\data_sc\lib\site-packages\arviz\stats\stats.py:248: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ics = ics.append([ic_func(dataset, pointwise=True, scale=scale, var_name=var_name)])
#         rank          loo     p_loo     d_loo    weight         se       dse  \
# code_4     0 -3699.176186  2.504819  0.000000  0.803333  29.963779  0.000000
# code_3     1 -3700.549032  2.170731  1.372846  0.196667  30.170284  2.203438
#
#         warning loo_scale
# code_4    False       log
# code_3    False       log

# %%
az.plot_compare(az_compare)
# Out:
# <AxesSubplot:xlabel='Log'>

# %%
compare_dict = {"code_3": arviz_result_3, "code_4": arviz_result_4}
az_compare = az.compare(compare_dict, ic="waic")
az_compare
# Out:
# d:\work\Anaconda\envs\data_sc\lib\site-packages\arviz\stats\stats.py:248: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ics = ics.append([ic_func(dataset, pointwise=True, scale=scale, var_name=var_name)])
# d:\work\Anaconda\envs\data_sc\lib\site-packages\arviz\stats\stats.py:248: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ics = ics.append([ic_func(dataset, pointwise=True, scale=scale, var_name=var_name)])
#         rank         waic    p_waic   d_waic    weight         se       dse  \
# code_4     0 -3699.176416  2.505049  0.00000  0.803353  29.963845  0.000000
# code_3     1 -3700.549136  2.170834  1.37272  0.196647  30.170297  2.203245
#
#         warning waic_scale
# code_4    False        log
# code_3    False        log

# %%
az.plot_compare(az_compare)
# Out:
# <AxesSubplot:xlabel='Log'>

# %% [markdown]
# Excercise 3

# %%
model_5 = CmdStanModel(stan_file='code_5.stan')

X = result_2.stan_variable("X")[0][:, 0:1]
K = 1
data = {"N": N, "y":y, "X": X, "K": K}

result_5 = model_5.sample(data=data, chains=4)
arviz_result_5 = az.from_cmdstanpy(posterior=result_5)
arviz_result_5
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
#
# chain 1 |▉         | 00:00 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
#
# chain 1 |██▎       | 00:00 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
#
# chain 1 |████      | 00:00 Iteration:  700 / 2000 [ 35%]  (Warmup)
#
#
# chain 1 |█████▉    | 00:01 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
# chain 1 |██████▊   | 00:04 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
# chain 1 |███████▋  | 00:06 Iteration: 1400 / 2000 [ 70%]  (Sampling)
# chain 1 |████████▏ | 00:07 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
#
#
# chain 1 |████████▋ | 00:09 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
#
# chain 1 |█████████ | 00:10 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
# chain 1 |█████████▌| 00:11 Iteration: 1800 / 2000 [ 90%]  (Sampling)
# chain 1 |██████████| 00:12 Iteration: 1900 / 2000 [ 95%]  (Sampling)
#
#
# chain 1 |██████████| 00:13 Sampling completed
# chain 2 |██████████| 00:13 Sampling completed
# chain 3 |██████████| 00:13 Sampling completed
# chain 4 |██████████| 00:13 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats

# %%
K = 2
X = result_2.stan_variable("X")[0][:, 0:K]
data = {"N": N, "y":y, "X": X, "K": K}

result_5_K_2 = model_5.sample(data=data, chains=4)
arviz_result_5_K_2 = az.from_cmdstanpy(posterior=result_5_K_2)
arviz_result_5_K_2
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
#
# chain 1 |▉         | 00:00 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
# chain 1 |█▎        | 00:00 Iteration:  100 / 2000 [  5%]  (Warmup)
#
#
# chain 1 |██▎       | 00:00 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
#
# chain 1 |███▏      | 00:00 Iteration:  500 / 2000 [ 25%]  (Warmup)
#
#
# chain 1 |████      | 00:00 Iteration:  700 / 2000 [ 35%]  (Warmup)
#
#
#
# chain 1 |█████     | 00:00 Iteration:  900 / 2000 [ 45%]  (Warmup)
#
#
#
# chain 1 |█████▉    | 00:02 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
# chain 1 |██████▎   | 00:04 Iteration: 1100 / 2000 [ 55%]  (Sampling)
#
#
# chain 1 |██████▊   | 00:05 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
# chain 1 |███████▎  | 00:07 Iteration: 1300 / 2000 [ 65%]  (Sampling)
#
#
# chain 1 |███████▋  | 00:08 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
# chain 1 |████████▏ | 00:10 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
# chain 1 |████████▋ | 00:11 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
#
# chain 1 |█████████ | 00:12 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
# chain 1 |█████████▌| 00:13 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 00:14 Iteration: 1900 / 2000 [ 95%]  (Sampling)
#
#
# chain 1 |██████████| 00:14 Sampling completed
# chain 2 |██████████| 00:14 Sampling completed
# chain 3 |██████████| 00:14 Sampling completed
# chain 4 |██████████| 00:14 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats

# %%
K = 3
X = result_2.stan_variable("X")[0][:, 0:K]
data = {"N": N, "y":y, "X": X, "K": K}

result_5_K_3 = model_5.sample(data=data, chains=4)
arviz_result_5_K_3 = az.from_cmdstanpy(posterior=result_5_K_3)
arviz_result_5_K_3
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
#
#
# chain 1 |▉         | 00:00 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
# chain 1 |█▊        | 00:00 Iteration:  200 / 2000 [ 10%]  (Warmup)
#
#
# chain 1 |███▏      | 00:00 Iteration:  500 / 2000 [ 25%]  (Warmup)
#
#
# chain 1 |████▌     | 00:00 Iteration:  800 / 2000 [ 40%]  (Warmup)
# chain 1 |█████▉    | 00:01 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
#
#
# chain 1 |██████▊   | 00:04 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
#
# chain 1 |███████▋  | 00:07 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
# chain 1 |████████▏ | 00:09 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
# chain 1 |████████▋ | 00:10 Iteration: 1600 / 2000 [ 80%]  (Sampling)
#
#
# chain 1 |█████████ | 00:12 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
# chain 1 |█████████▌| 00:13 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 00:14 Iteration: 1900 / 2000 [ 95%]  (Sampling)
# chain 1 |██████████| 00:14 Sampling completed
# chain 2 |██████████| 00:14 Sampling completed
# chain 3 |██████████| 00:14 Sampling completed
# chain 4 |██████████| 00:14 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats

# %% [markdown]
# Compare models

# %%
compare_dict = {"K = 1": arviz_result_5, "K = 2": arviz_result_5_K_2, "K = 3": arviz_result_5_K_3}
az_compare = az.compare(compare_dict, ic="waic")
az_compare
# Out:
# d:\work\Anaconda\envs\data_sc\lib\site-packages\arviz\stats\stats.py:248: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ics = ics.append([ic_func(dataset, pointwise=True, scale=scale, var_name=var_name)])
# d:\work\Anaconda\envs\data_sc\lib\site-packages\arviz\stats\stats.py:248: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ics = ics.append([ic_func(dataset, pointwise=True, scale=scale, var_name=var_name)])
# d:\work\Anaconda\envs\data_sc\lib\site-packages\arviz\stats\stats.py:248: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ics = ics.append([ic_func(dataset, pointwise=True, scale=scale, var_name=var_name)])
#        rank         waic    p_waic      d_waic    weight         se  \
# K = 3     0 -2244.780698  4.061712    0.000000  0.994659  29.390446
# K = 2     1 -2440.712785  3.033478  195.932087  0.000000  28.764341
# K = 1     2 -2903.517582  2.072986  658.736883  0.005341  29.506534
#
#              dse  warning waic_scale
# K = 3   0.000000    False        log
# K = 2  19.044068    False        log
# K = 1  30.963077    False        log

# %%
az.plot_compare(az_compare)
# Out:
# <AxesSubplot:xlabel='Log'>

# %%
az_compare = az.compare(compare_dict)
az_compare
# Out:
# d:\work\Anaconda\envs\data_sc\lib\site-packages\arviz\stats\stats.py:248: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ics = ics.append([ic_func(dataset, pointwise=True, scale=scale, var_name=var_name)])
# d:\work\Anaconda\envs\data_sc\lib\site-packages\arviz\stats\stats.py:248: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ics = ics.append([ic_func(dataset, pointwise=True, scale=scale, var_name=var_name)])
# d:\work\Anaconda\envs\data_sc\lib\site-packages\arviz\stats\stats.py:248: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ics = ics.append([ic_func(dataset, pointwise=True, scale=scale, var_name=var_name)])
#        rank          loo     p_loo       d_loo    weight         se  \
# K = 3     0 -2244.780611  4.061625    0.000000  0.994659  29.390441
# K = 2     1 -2440.713124  3.033816  195.932513  0.000000  28.764389
# K = 1     2 -2903.517599  2.073003  658.736987  0.005341  29.506525
#
#              dse  warning loo_scale
# K = 3   0.000000    False       log
# K = 2  19.044088    False       log
# K = 1  30.963069    False       log

# %%
az.plot_compare(az_compare)
# Out:
# <AxesSubplot:xlabel='Log'>
